# %% [markdown]
# ### NetworkX
#
# a rapid thematic analysis of a small corpus. For more information. We start by word coulds of each chapters and then we aim to use graph presentation of data.

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd
#import tensorflow as tf  # conda install -c conda-forge tensorflow 
#import tensorflow_hub as hub  #-c conda-forge tensorflow-hub
from sklearn import preprocessing 

#!python -m spacy download en_core_web_md #you will need to install this on first load
import spacy
from spacy.lang.en import English
from spacy import displacy
#nlp = spacy.load('en_core_web_md')
from IPython.display import HTML
import logging
#logging.getLogger('tensorflow').disabled = True #OPTIONAL - to disable outputs from Tensorflow
import plotly.plotly as py  #conda install -c plotly plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0b4129170776> in <module>
#      14 import logging
#      15 #logging.getLogger('tensorflow').disabled = True #OPTIONAL - to disable outputs from Tensorflow
# ---> 16 import plotly.plotly as py  #conda install -c plotly plotly
#      17 import plotly.graph_objs as go
#      18 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ## Data

# %% [markdown]
# Please download the data '01_df_v013.pickle' in github on  your local machine from  this directory :<br />
#  https://github.com/grasshoff/vorlesung2019/tree/master/notebooks/yeghaneh/data
#  <br /><br />
# The data 01_df_v013 is annotated (labeled) data of english version of well-known kepler's book: New Astronomy (Latin: Astronomia nova). You can find that in the repository.

# %%
importVersion = '013'  # The  desired version pickle-file of your data (now we are working on version 013 of our data)

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion) # Put the path of the data in your local machine here, consider the letter "r" before the path

# %% [markdown]
# ### Pre-processing

# %%
dfAstroNova = pd.read_pickle(path)# The data  is saved as a pickle file. We read it as a pandas dataFrame
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
 # Sort the data based on the chapters of the book. 
dfAstroNova['chapter'] = dfAstroNova.chapter.replace("appendix b",np.nan).astype(float)  
dfAstroNova = dfAstroNova.rename_axis('MyIdx').sort_values(by = ['chapter', 'MyIdx'], ascending = [True, True])
dfAstroNova.chapter.fillna('appendix b', inplace=True)

# %%
len(dfAstroNova)   # Number of rows.
# Out:
# 1605

# %%
dfAstroNova.head(5)
# Out:
#                                                     html  \
# MyIdx
# 18     <p><span class="anchor" id="bookmark0"></span>...
# 19     <p><span class="anchor" id="bookmark1"></span>...
# 20     <p>The testimony of the ages confirms that the...
# 21     <p><img height="382" src="media/image1.jpeg" w...
# 22     <p>Before the distinction between the first mo...
#
#                                                     text links   italic  \
# MyIdx
# 18                                             Chapter 1    []       []
# 19     On the distinction between the first motion an...    []       []
# 20     The testimony of the ages confirms that the mo...    []       []
# 21     It is just this from which astronomy arose amo...    []       []
# 22     Before the distinction between the first motio...    []  [(such]
#
#       chapter       graphic table  \
# MyIdx
# 18          1            []    []
# 19          1            []    []
# 20          1            []    []
# 21          1  [ ch 1 gr 1]    []
# 22          1            []    []
#
#                                                 marginal  \
# MyIdx
# 18                                                    []
# 19                                                    []
# 20     [ Terms: 1. The first motion is that of the wh...
# 21                                                    []
# 22                                                  [ 2]
#
#                                                sentences  \
# MyIdx
# 18                                           [Chapter 1]
# 19     [On the distinction between the first motion a...
# 20     [The testimony of the ages confirms that the m...
# 21     [It is just this from which astronomy arose am...
# 22     [Before the distinction between the first moti...
#
#                                                   tagged
# MyIdx
# 18                         [[(Chapter, None), (1, NUM)]]
# 19     [[(On, None), (the, None), (distinction, None)...
# 20     [[(The, None), (testimony, None), (of, None), ...
# 21     [[(It, None), (is, None), (just, None), (this,...
# 22     [[(Before, None), (the, None), (distinction, N...

# %%
texts=[]
for sen in dfAstroNova.sentences:
    texts +=sen

# %%
type(texts)
# Out:
# list

# %%
str1 = ''.join(texts)

# %% [markdown]
# # All Chapters

# %%
#Word cloud
from os import path  
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
stopwords=set(STOPWORDS)
stop_words=stopwords.union(["Therefore","But" ,"would" ,"but", "also", "let", 'I' , 'And',  'For', 'A' ,'The','will','now'])
wordcloud = WordCloud(background_color="white", max_words=2000,
               stopwords=stop_words, contour_width=3, contour_color='steelblue' )
wc=wordcloud.generate(str1)
print(wc)
fig = plt.figure(figsize=(10,15))
plt.imshow(wc)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=1800)

# %%
def chapter_wordcloud(chapter_number):
    df=dfAstroNova[dfAstroNova.chapter==chapter_number]
    texts=[]
    for sen in df.sentences:
        texts +=sen
    stopwords=set(STOPWORDS)
    stop_words=stopwords.union(["Therefore","But" ,"would" ,"but", "also", "let", 'I' , 'And',  'For', 'A' ,'The','will','now'])
    str2 = ''.join(texts)
    wordcloud = WordCloud(background_color="white", max_words=2000,
                   stopwords=stop_words, contour_width=3, contour_color='steelblue' )
    wc=wordcloud.generate(str2)
    print(wc)

    fig = plt.figure(figsize=(10,15))
    plt.imshow(wc)
    plt.axis('off')
    plt.show()
    name='WordCloudCloud.png{0}.png'.format(chapter_number)
    fig.savefig(name, dpi=1800)
    return

# %% [markdown]
# # Chapter 4

# %%
chapter_wordcloud(4)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000002987363E908>

# %% [markdown]
# # Chapter 10

# %%
chapter_wordcloud(10)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000029874906BC8>

# %%
chapter_wordcloud(27)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000029874912688>
